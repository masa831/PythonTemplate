# %%
from check_ipynb import check_notebooks_in_folder

# %%
path = r'.\testenv'

# %%
check_notebooks_in_folder(path)
# Out:
# .\testenv\test1.ipynb: クリアされていないセルの出力があります。
# .\testenv\test2.ipynb: 全てのセルの出力はクリアされています。
# .\testenv\test3.ipynb: クリアされていないセルの出力があります。
# .\testenv\test4.ipynb: 全てのセルの出力はクリアされています。
