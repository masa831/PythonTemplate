# %%
import decorator_sample as deco

# %%
deco.test_decorator(1,2,3)
# Out:
# Calling add with args: (1, 2), kwargs: {}
# add returned 3
# Calling add3 with args: (3, 2, 3), kwargs: {}
# add3 returned 8
# test_decorator took 0.0000 seconds to execute
# 11
