# %%
import sys
from pathlib import Path

# srcをimportできるようにパスを追加
# sys.path.append(str(Path().resolve().parent))  # test.ipynb用
sys.path.append(str(Path().resolve().parent.parent))  # test.ipynb用

# %%
from src.util import find_absolute_path

path = find_absolute_path('data/input.csv')
path
# Out:
# 'd:\\work\\PythonTemplate\\get_abspath\\data\\input.csv'

# %%
path = find_absolute_path('data/inputss.csv')
path
