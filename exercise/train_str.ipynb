# %% [markdown]
# # 文字列操作まとめ

# %% [markdown]
# Q 任意の文字列を結合

# %%
a = 'hello,'
b = 'world'
# Out:
# helloworld

# %% [markdown]
# Q 文字列リストの要素を結合する　,　を挟む場合と、そのまま結合する場合どちらも

# %%
s = ['dog', 'cat', 'penguin']
# Out:
# dog,cat,penguin
# dogcatpenguin

# %% [markdown]
# Q 指定の文字列を繰り返す

# %%
a = 'hello,'
# Out:
# hello,hello,hello,

# %% [markdown]
# Q 文字列を置換する　完全一致

# %%
a = 'hello,world!!'
# Out:
# hello,world??

# %% [markdown]
# Q 文字列を置換する　部分一致　正規表現
#
# <https://note.nkmk.me/python-str-replace-translate-re-sub/#resub-resubn>
#
# re.sub() 第一引数が正規表現パターン、第二が置換先文字列、第三が置換対象

# %%
import re

s = 'aaa@xxx.com bbb@yyy.net ccc@zzz.org'
# Out:
# ABC@xxx.com ABC@yyy.net ABC@zzz.org

# %% [markdown]
# Q 前方一致、後方一致

# %%
a = 'aaa;bbb;ccc'
# Out:
# True
# True

# %% [markdown]
# Q 検索　文字列に検索対象が入っているかを確認する

# %%
a = 'hello,world!!'
tg = 'b'
# Out:
# -1
# 2

# %% [markdown]
# Q ある文字列に部分文字列として存在するかどうか

# %%
a = 'hello, world'
tg = 'hello'
# Out:
# True
# False

# %% [markdown]
# Q ある文字列に部分文字列として存在するかどうか
# 正規表現バージョン

# %%
import re
a = 'hello, world'
tg = 'hello'
# Out:
# <re.Match object; span=(0, 5), match='hello'>
# None

# %% [markdown]
# Q 両端の空白削除

# %%
a = ' x '
# Out:
# AxB
# Ax B
# A xB

# %% [markdown]
# Q 両端の不要な文字列を削除する

# %%
a = 'FF_abc'

a = 'abc_AF'
# Out:
# abc
# abc
# abc
# abc

# %% [markdown]
# Q 大文字にする、小文字にする

# %%
a = 'Hello'
# Out:
# HELLO
# hello

# %% [markdown]
# Q 文字列を分割して、リストを生成する

# %%
a = 'one, two three; four\nfive'
# Out:
# ['one,', 'two', 'three;', 'four', 'five']

# %% [markdown]
# Q 区切り文字を指定して分割

# %%
a = 'one, two three; four\nfive'
# Out:
# ['one,', 'two', 'three;', 'four\nfive']

# %% [markdown]
# Q 改行で分割

# %%
a = 'one, two\n three; four\nfive'
# Out:
# ['one, two', ' three; four', 'five']

# %% [markdown]
# <https://note.nkmk.me/python-split-rsplit-splitlines-re/>
