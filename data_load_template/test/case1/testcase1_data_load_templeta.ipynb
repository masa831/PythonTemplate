# %%
# 自作モジュールを自動でリロードする
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

# srcをimportできるようにパスを追加
sys.path.append(str(Path().resolve().parent.parent))  # test.ipynb用
# sys.path.append(str(Path().resolve()))         # main.ipynb用

# %%
list(Path().resolve().parents)
# Out:
# [WindowsPath('D:/work/PythonTemplate/data_load_template/test'),
#  WindowsPath('D:/work/PythonTemplate/data_load_template'),
#  WindowsPath('D:/work/PythonTemplate'),
#  WindowsPath('D:/work'),
#  WindowsPath('D:/')]

# %%
from src import loader

# %%
# df = loader.bf_load_csv("sample.csv")
# print(df.head())

# %%
df = loader.load_csv("sample.csv")
print(df.head())
# Out:
# [DBG] current=WindowsPath('D:/work/PythonTemplate/data_load_template/test/case1')
# [DBG] path=WindowsPath('D:/work/PythonTemplate/data_load_template/data/sample.csv')
#    id  name  age
# 0   0  john   23
# 1   1  taro   30
# 2   2   ken   10
