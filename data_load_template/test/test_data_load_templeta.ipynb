# %%
# 自作モジュールを自動でリロードする
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

# srcをimportできるようにパスを追加
sys.path.append(str(Path().resolve().parent))  # test.ipynb用
# sys.path.append(str(Path().resolve()))         # main.ipynb用

# %%
from src import loader

df = loader.load_csv("sample.csv")
print(df.head())
# Out:
#    id  name  age
# 0   0  john   23
# 1   1  taro   30
# 2   2   ken   10

# %%
df = loader.bf_load_csv("sample.csv")
print(df.head())
# Out:
#    id  name  age
# 0   0  john   23
# 1   1  taro   30
# 2   2   ken   10
