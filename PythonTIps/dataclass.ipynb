# %% [markdown]
# ##  dataclassの使いかた
#
#
# <https://qiita.com/CinnamonSea2073/items/2cae34c3dd7ff86d0950>
#
# <https://zenn.dev/karaage0703/articles/3508b20ece17d4>

# %%
from dataclasses import dataclass, field

@dataclass
class Person:
    name: str
    age: int
    address: str = 'tokyo'
    book : list = field(default_factory=list)
    y: dict = field(default_factory=dict)
    z: set = field(default_factory=set)
    active : bool = field(default=True, repr=False)  # repr=Falseとすると、printで表示されない
    info : str = field(init=False)

    # __post_init__を使うと初期化後に処理を追加できる
    def __post_init__(self):
        self.info = self.name + '/' + self.address

# %%
taro = Person('taro', 30, 'tyokyo')

# %%
taro
# Out:
# Person(name='taro', age=30, address='tyokyo', book=[], y={}, z=set(), info='taro/tyokyo')

# %%
# 引数が足りないとエラー
# hitosi = Person('hitoshi')

# %%
ken = Person('ken', 30, 'osaka')

# データにアクセスする
print(f'{ken.name=}')
print(f'{ken.age=}')
print(f'{ken.address=}')
print(f'{ken.active=}')  # repr=Falseでも同様にアクセスできる
# Out:
# ken.name='ken'
# ken.age=30
# ken.address='osaka'
# ken.active=True

# %%
# dict型へ変換できる
from dataclasses import asdict, astuple

print(asdict(ken))
# Out:
# {'name': 'ken', 'age': 30, 'address': 'osaka', 'book': [], 'y': {}, 'z': set(), 'active': True, 'info': 'ken/osaka'}

# %%
print(astuple(ken))
# Out:
# ('ken', 30, 'osaka', [], {}, set(), True, 'ken/osaka')

# %%
# Frozen変数を使うことでイミュータブルにできる
@dataclass(frozen=True)
class homekey():
    no: int = 100
    password: str = "AAA"

# %%
mykey = homekey()
mykey.no = 200  # Error
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[32], line 2
#       1 mykey = homekey()
# ----> 2 mykey.no = 200  # Error
#
# File <string>:4, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'no'
