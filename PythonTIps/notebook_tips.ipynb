# %% [markdown]
# ## jupyter notebookのtips集

# %%
# 自作モジュールを自動でリロードする
# %load_ext autoreload
# %autoreload 2

# %%
# pythonパス確認
import sys
print(sys.path)
# Out:
# ['C:\\Users\\zeroc\\AppData\\Local\\Programs\\Python\\Python38\\python38.zip', 'C:\\Users\\zeroc\\AppData\\Local\\Programs\\Python\\Python38\\DLLs', 'C:\\Users\\zeroc\\AppData\\Local\\Programs\\Python\\Python38\\lib', 'C:\\Users\\zeroc\\AppData\\Local\\Programs\\Python\\Python38', 'd:\\work\\PythonTemplate\\.venv', '', 'd:\\work\\PythonTemplate\\.venv\\lib\\site-packages', 'd:\\work\\PythonTemplate\\.venv\\lib\\site-packages\\win32', 'd:\\work\\PythonTemplate\\.venv\\lib\\site-packages\\win32\\lib', 'd:\\work\\PythonTemplate\\.venv\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# ### magicコマンド
# - 基本的なmagic command
#   - <https://www.mitsuru-takahashi.net/blog/ipython-magic-commands/>
# - ?, ??コマンド
#   - <https://note.nkmk.me/jupyter-notebook-ipython-lsmagic/>

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\zeroc\\AppData\\Roaming',
#  'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_25868_BIMPDFBNMGNUQUPK',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'MSGAMINGPC',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'EFC_3208': '1',
#  'ELECTRON_RUN_AS_NODE': '1',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\zeroc',
#  'JPY_INTERRUPT_EVENT': '2172',
#  'LOCALAPPDATA': 'C:\\Users\\zeroc\\AppData\\Local',
#  'LOGONSERVER': '\\\\MSGAMINGPC',
#  'NUMBER_OF_PROCESSORS': '12',
#  'ONEDRIVE': 'C:\\Users\\zeroc\\OneDrive',
#  'ONEDRIVECONSUMER': 'C:\\Users\\zeroc\\OneDrive',
#  'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#  'OS': 'Windows_NT',
# ...

# %%
# %time?
# Out:
# Docstring:
# Time execution of a Python statement or expression.
#
# The CPU and wall clock times are printed, and the value of the
# expression (if any) is returned.  Note that under Win32, system time
# is always reported as 0, since it can not be measured.
#
# This function can be used both as a line and cell magic:
#
# - In line mode you can time a single-line statement (though multiple
#   ones can be chained with using semicolons).
#
# - In cell mode, you can time the cell body (a directly
#   following statement raises an error).
#
# This function provides very basic timing functionality.  Use the timeit
# magic for more control over the measurement.
#
# .. versionchanged:: 7.3
#     User variables are no longer expanded,
#     the magic line is always left unmodified.
#
# Examples
# --------
# ::
#
#   In [1]: %time 2**128
#   CPU times: user 0.00 s, sys: 0.00 s, total: 0.00 s
#   Wall time: 0.00
#   Out[1]: 340282366920938463463374607431768211456L
#
#   In [2]: n = 1000000
# ...

# %%
import math
math.sqrt?
# Out:
# Signature: math.sqrt(x, /)
# Docstring: Return the square root of x.
# Type:      builtin_function_or_method

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %% [markdown]
# ### 時間計測
# <https://ensekitt.hatenablog.com/entry/2017/11/17/200000>

# %%
# %%time
# セルの実行時間を計測する
a = [x ** 2 for x in range(100000)]
sum(a)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 17 ms
# 333328333350000

# %%
# %%timeit
# セルの実行時間を計測する
a = [x ** 2 for x in range(100000)]
sum(a)
# Out:
# 12.8 ms ± 181 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
