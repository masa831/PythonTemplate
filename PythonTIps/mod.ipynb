# %% [markdown]
# ##  剰余演算

# %% [markdown]
# ---

# %% [markdown]
# 基本的な演算例

# %%
10 % 3
# Out:
# 1

# %%
9 % 3
# Out:
# 0

# %%
# 割る数が大きい場合
# 商 0 , 余り14
5 % 14
# Out:
# 5

# %%
# 負の数の剰余
# 商 -1 , 余り(-5 + 14) = 9
-5 % 14
# Out:
# 9

# %%
# 商は//でえられる
-5 // 14
# Out:
# -1

# %%
# 商、剰余の両方を得る
q, mod = divmod(-5, 14)
print(f'{q=}, {mod=}')
# Out:
# q=-1, mod=9
