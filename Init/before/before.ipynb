# %% [markdown]
# __init__.pyの使い方について
#
# 参考URL:<https://qiita.com/herr-shigeo/items/9f3ef8de1c5c9561d905>
#
# __init__をおいて、内部に所定の記載をすれば、moduleの呼び出しのみで関数等を使用できるようになる。

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# __init__.pyがutil内にない時は、ファイルごとに指定する必要がある。
import util.hello
import util.morning

# %%
util.hello.sayhello()
# Out:
# hello

# %%
util.morning.saymorning()
# Out:
# good morning
