# %% [markdown]
# __init__.pyの使い方について
#
# 参考URL:<https://qiita.com/herr-shigeo/items/9f3ef8de1c5c9561d905>
#
# __init__をおいて、内部に所定の記載をすれば、moduleの呼び出しのみで関数等を使用できるようになる。

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# util内に__init__.pyを置き、内部で各ファイルをfrom,importすると、
# module名から直接関数等を呼び出せる。
import util

# %%
util.sayhello()
# Out:
# hello

# %%
util.saymorning()
# Out:
# good morning
